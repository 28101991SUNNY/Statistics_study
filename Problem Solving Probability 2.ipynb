# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Confidence Interval

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.stats import norm

# %% [markdown]
# # Example :
# ## Insurance company : has given 25000 policies' , yearly claim's mean = 320 and standard deviation = 540 "
# ##  we want to know approximately what is the probability that claim is greater than 8.3 million

# %% [raw]
# n = 25000
# mean = 320 yearly claims mean
# y = 8300000
# ybar = n*p = 25000*320
# std = 540 yealy claims
# var(y) = sigma^2 * n

# %%
25000*320
# Out:
# 8000000

# %%
std = sq(var(y)) = sq(n)*540

# %%
540*np.sqrt(25000)
# Out:
# 85381.49682454625

# %%
(8300000-8000000)/(85381.49682454625)
# Out:
# 3.513641844631532

# %%
1-norm.cdf(3.5136)
# Out:
# 0.00022103898833181201

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [raw]
# mean = 1000  # weekly demand mean
# std = 200    # weekly
#
# P[demand < 1100 for next two weeks each ]

# %% [raw]
# Z = x-mean / std
#
# x = (1100-1000) / 200

# %%
(1100-1000) / 200
# Out:
# 0.5

# %%
from scipy.stats import norm

# %%
norm.cdf(0.5)  # for first week
# Out:
# 0.6914624612740131

# %% [raw]
# P[demand < 1100 for week 1 ] * P[demand < 1100 for week 2 ]
# #(independent events)
# P[x1 <= 1100] * P[x2 <= 1100]
# since for both weeks , sigma and mean is same .
#
# = P[demand < 1100 for a week] * P[demand < 1100 for a week]
# = 0.6914 * 0.6914

# %%
0.6914 * 0.6914
# Out:
# 0.47803396000000004

# %% [markdown]
# ### what is the probability that he will run out of inventory !

# %% [raw]
# # What is the probability that his stock will get over in 2 weeks
#
# varinace = sigma^2 = 200^2 = 40000
#
# Y = x1 + x2
#
# P[x1 + x2 > 2200]=  ?

# %%
E(Y) = E(X1) + E(X2)
     = 1000 + 1000
     = 2000
        
Var(Y) = nVar(X) 
    =  2 * ((200)^2)
    = 80000

# %%
2 * ((200)**2)
# Out:
# 80000

# %% [raw]
# z = Y - E(Y)
#     / sq(Var(Y))

# %%
norm.cdf((2200-2000)/np.sqrt(80000))   #
# Out:
# 0.7602499389065233

# %%
# 1-P[x1 + x2 < 2200] =  1 - P[x1 + x2 > 2200]
1-0.76024
# Out:
# 0.23975999999999997

# %%
0.24
# Out:
# 0.24

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## toss a coin , P[H] = p , till i get the first H.
#
# ## X : number of tosses . P[X = 5] = ?

# %% [raw]
# S = {H,HT,HHT,HHHT,HHHHT,HHHHHT....}
#
# P[H] = p
# P[T] = 1-p
#
# P[X=5] = P[HHHHT]
#        = p*(1-p)^4

# %% [raw]
#      H       E(X|H) = 1
# X
#      T       E(X|T) = 1 + E[X]  # T + repeat till gets H

# %% [raw]
# E(X) = E(X|H)*P[H] + E(X|T)*P[T]
#      =    1  * p   + (1+E(X))*(1-p)
#
# E(X) = 1/p

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# definind sample space :
#     till get heads , A and B keep tossing alternatively .
#
#     S = { H, TH, TTH ,TTTH ,TTTTH , TTTTTH , ........ }
#
#     since A starts the tossing :
#
#     S = { H, TH, TTH ,TTTH ,TTTTH , TTTTTH , TTTTTTH........ }
#           A      ABA        ABABA            ABABABA ....
#
#             in above cases A wins (Q)
#
#        P[first event] = H : 1/2 :  p                                                  p
#        P[3rd event] = TTH : 1/8 :  (1-p)(1-p)*p                           (1-p)**2  * p
#        P[5th event]       :     :  (1-p)(1-p)(1-p)(1-p) * p               (1-p)**4  * p
#        P[7th event]             :  (1-p)(1-p)(1-p)(1-p)(1-p)(1-p)*p       (1-p)**6  * p
#        .
#        .
#        .
#        .
# P[A wins] = P    +    (1-p)^2  * p    +  (1-p)^4  * p     +   (1-p)^6  * p  +  .....
#
# lets say (1-p)^2 = r
#
# P[A wins] = p + rp + r^2p + r^3p +.....
#
#
#
# sum of above GP :
#
# P[A wins] = P / 1-r
#           = p / (1-((1-p)^2))
#             = 1 / (2-p)
#
#
#             Option 4 : is given wrong
#
#             ans is : 1/(2-p)

# %% [markdown]
# ## X      :   0   ,  1 ,    3
# ## P(X) :  0.2  ,0.3 , 0.5
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Y = x1+x2+x3+......+xn
#
# E(x) = 3.5
# Var(x) = 35/12
#
# for 10 tosses : E(y) = 10*3.5 = 35
#                Var(y)= 35/12 * 10 = 350/12

# %% [raw]
# Y-E(y)/sq(Var(y))

# %%
(30-35)/(np.sqrt(350/12))
# Out:
# -0.9258200997725515

# %%
(40-35)/(np.sqrt(350/12))
# Out:
# 0.9258200997725515

# %%
norm.cdf(0.9258)-norm.cdf(-0.9258)
# Out:
# 0.6454500728068715

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Y = x1 + x2 + x3 + ..... x12

# %% [raw]
# xi - lifetime of the ith battery

# %% [raw]
# meanlifetime = 5 weeks per battery
# deviation = 1.5 weeks per battery

# %% [raw]
# Q : P[y < 52] =  ?
# P[needing 13 or more batteries in a year] = P[12 batteries died in a year]

# %% [raw]
# 52 weeks in 12 months

# %% [raw]
# E(xi) = 5
# E(y) = 12 * 5 = 60
# Var(y) = 12*(1.5)^2

# %% [raw]
# P[y<52] = (52-60)/(np.sqrt(12*1.5**2))

# %%
(52-60)/(np.sqrt(12*1.5**2))
# Out:
# -1.539600717839002

# %%
norm.cdf(-1.5396)
# Out:
# 0.0618289427437204

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# E(x) = 3.5
# Var(X) = 35/12
#
# E(y) = n*E(x) = 140*3.5
# Var(y) = n*Var(x) = 140*(35/12)

# %% [raw]
# P[sum of frist 140 rolls < 450]

# %%
Y = x1 + x2 + x3 + ....... + x140

# %%
P[y <= 450] = P[ Z < (450-(140*3.5))/np.sqrt((140*(35/12))) ]

# %%
(450-(140*3.5))/np.sqrt((140*(35/12)))
# Out:
# -1.979486637221574

# %%
norm.cdf(-1.9794)
# Out:
# 0.02388549425622993

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
(104-100)/(20/np.sqrt(16))
# Out:
# 0.8

# %%
norm.cdf((104-100)/(20/np.sqrt(16)))
# Out:
# 0.7881446014166034

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
norm.cdf((104-100)/(20/np.sqrt(16)))-norm.cdf((98-100)/(20/np.sqrt(16)))
# Out:
# 0.44356634302692755

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
norm.cdf((82-77)/(15/np.sqrt(25)))-norm.cdf((72-77)/(15/np.sqrt(25)))
# Out:
# 0.9044192954543706

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# average test score in batch 1 x1
# average test score in batch 2 x2
#
# P[x1 > x1] ?
#
# x1 - x2 > 0 we need
#
# Y = X1-X2 bar
#
# E(y)  = E(x1) - E(x2)
#       = 77  - 77
#       = 0
#
#     Y is a gaussian with mean is 0 .
#
#     so P[y > 0] = 0.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Z = X-E(X)/std

X = Z*std + E(x)

# %%
norm.ppf(.80)
# Out:
# 0.8416212335729143

# %%
0.8416212335729143 *  15 + 100
# Out:
# 112.62431850359371
