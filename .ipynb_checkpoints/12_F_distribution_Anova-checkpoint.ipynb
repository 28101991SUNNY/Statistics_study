# %%
import statsmodels.api as sm
from scipy.stats import norm
from scipy.stats import t
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import figure
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Analysis of variance

# %% [markdown]
# - Analysis of variance (ANOVA) is a collection of statistical models and their associated estimation procedures (such as the "variation" among and between groups) used to analyze the differences among means.
# - ANOVA was developed by the statistician Ronald Fisher.
# - ANOVA is based on the law of total variance, where the observed variance in a particular variable is partitioned into components attributable to different sources of variation.
# - In its simplest form, ANOVA provides a statistical test of whether two or more population means are equal, and therefore generalizes the t-test beyond two means.
# - In other words, the ANOVA is used to test the difference between two or more means.

# %% [markdown]
# ### problem with multiple t-tests :
#
# - multiple t-test even at small significance level , can result in a high probability of false positive error ( incorrectly rejecting null hypothesis.  )
# - if the result of one hypothesis test is : mean1 = mean2
# - and another hypothesis test result is mean2 = mean3.
# - we cannot conclude that mean1 = mean2 = mean3.
# - as the type 1 error (alfa)(false +ve) multiplies.

# %% [markdown]
# ### Assumptions :
#
# - independence of observations
# - distibutions of the residuals are normal.
# - equality of variance : homoscedasticity - the variance of data in groups should be the same.

# %% [markdown]
# ### Partitioning of the sum of squares :

# %% [markdown]
# -  The definitional equation of sample variance is
#
# ![image.png](attachment:image.png)
#
#  - where the divisor is called the degrees of freedom (DF), the summation is called the sum of squares (SS), the result is called the mean square (MS) and the squared terms are deviations from the sample mean.

# %% [markdown]
# - ANOVA estimates 3 sample variances:
#     - a total variance based on all the observation deviations from the grand mean
#     - an error variance based on all the observation deviations from their appropriate treatment means a treatment variance.
#     - The treatment variance is based on the deviations of treatment means from the grand mean
# - the result being multiplied by the number of observations in each treatment to account for the difference between the variance of observations and the variance of means.

# %% [markdown]
# > The fundamental technique is a partitioning of the total sum of squares SS into components related to the effects used in the model.
# For example, the model for a simplified ANOVA with one type of treatment at different levels.
#
# ![image.png](attachment:image.png)
#
# >The number of degrees of freedom DF can be partitioned in a similar way: one of these components (that for error) specifies a chi-squared distribution which describes the associated sum of squares, while the same is true for "treatments" if there is no treatment effect.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
#  #### SST =  SSE + SSC
#
#     - SST : total/ overall sum of squares
#         > sum of squares between each data point and the overall mean
#
#     - SSC : column/between/treatment sum of ssquares
#         > sum of squares  between each group mean and overall mean
#
#     - SSE : Within/error sum of squares
#         > sum of squares between each data points and their own group mean

# %% [markdown]
# ### The F-test :

# %% [markdown]
# - The F-test is used for comparing the factors of the total deviation. For example, in one-way, or single-factor ANOVA, statistical significance is tested for by comparing the F test statistic
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# lets say if we want to test the recovery time of all given 7 drugs are equal or not!

# %%
drug1 = np.random.normal(4.0,0.2,50)
drug2 = np.random.normal(4.0,0.2,50)
drug3 = np.random.normal(4.0,0.2,50)
drug4 = np.random.normal(4.0,0.2,50)
drug5 = np.random.normal(4.0,0.2,50)
drug6 = np.random.normal(4.0,0.2,50) 
drug7 = np.random.normal(4.0,0.2,50)

# %%
data = pd.DataFrame([drug1,drug2,drug3,drug4,drug5,drug6,drug7]).T

# %%
data.columns = ["drug1","drug2","drug3","drug4","drug5","drug6","drug7"]

# %%
data
# Out:
#        drug1     drug2     drug3     drug4     drug5     drug6     drug7
# 0   3.901537  4.295903  3.901227  4.021824  4.430117  3.794902  4.127478
# 1   4.140125  3.900369  3.569446  4.030061  4.361243  3.827261  3.983712
# 2   4.158193  4.127469  4.246845  4.141104  3.768614  3.670279  3.893244
# 3   3.733953  3.775608  3.896946  4.635956  3.883147  3.905008  3.968151
# 4   3.925810  3.892121  3.790849  3.995478  4.008429  3.840468  4.288380
# 5   4.128361  4.033271  3.855636  3.697431  4.135255  4.072602  3.927466
# 6   4.127237  3.962498  3.967129  4.072554  4.491441  3.780391  4.345378
# 7   4.012842  3.628802  4.052504  3.926250  4.034204  4.086574  4.224207
# 8   3.902635  3.944068  3.966492  4.008424  4.064658  4.190458  3.637151
# 9   3.836433  3.700822  3.813226  3.776604  3.819343  3.569541  3.730848
# 10  4.294699  4.199871  4.012213  4.025107  4.442772  4.057380  3.674864
# 11  4.107701  4.116407  4.021463  4.137157  3.775299  4.417892  4.384300
# 12  3.982826  3.824696  4.119235  4.442812  3.884025  4.017676  3.840451
# 13  3.713727  3.741908  4.177190  4.162970  3.777764  4.179323  3.778626
# 14  3.833069  3.612462  4.287545  3.874668  3.991215  3.986342  4.002048
# 15  4.288348  4.399167  3.901233  3.896736  3.980184  4.100126  3.913111
# 16  4.410710  4.149187  3.775328  3.875963  4.092970  3.909532  4.448642
# 17  4.171925  3.877779  4.216417  4.645918  3.894121  3.855900  3.868027
# 18  4.134809  3.837619  3.738498  3.696935  4.091563  4.003680  4.042204
# 19  3.760730  3.844229  4.215499  3.972365  3.946261  3.929867  3.914966
# 20  3.911198  3.999019  4.176591  3.930874  3.895453  4.190086  3.853120
# 21  3.931958  4.271919  3.886801  3.989046  3.859771  4.119364  4.231521
# 22  3.619749  3.840472  4.068316  4.184864  4.305690  3.998420  3.913645
# 23  4.140906  3.788738  3.844013  4.222487  4.094565  3.941809  4.084862
# 24  3.802649  3.907703  3.901617  3.837230  3.776289  3.935229  4.146574
# 25  3.862654  4.217732  4.125821  3.909794  3.964997  3.781737  3.797452
# 26  4.026802  3.932671  3.877703  3.901528  4.279114  4.161743  4.236865
# 27  3.819025  3.669970  3.944974  3.954996  3.915604  4.175591  3.985353
# 28  4.021772  3.878075  4.047354  4.045108  3.647389  3.939164  3.917025
# 29  4.099327  3.966849  4.106955  3.877851  3.750075  3.964317  4.064036
# 30  3.893277  3.930381  3.557469  4.052865  4.173467  4.321823  4.171878
# 31  4.144223  3.884230  3.589871  4.077316  3.875001  3.933120  4.004920
# 32  4.131725  4.008353  3.849325  4.627740  3.865015  3.935392  3.761423
# 33  3.638411  3.788603  3.762648  3.955439  4.403098  4.000220  3.754467
# 34  4.111743  4.076635  4.069233  4.053559  3.813954  3.717224  3.924053
# 35  3.946347  4.203533  3.882780  4.203149  3.871762  3.985283  4.069321
# 36  3.957723  3.778014  4.029532  4.170947  4.040704  3.868295  4.032376
# 37  3.868260  4.125096  4.054972  4.105787  4.467859  4.288397  3.795281
# 38  4.197501  4.052141  3.814943  3.768934  3.584141  4.134030  3.893302
# 39  4.097794  4.083152  4.343155  4.216498  4.229254  4.076749  3.893464
# 40  4.208350  3.869683  4.406533  3.957044  3.899390  4.352796  3.806243
# 41  4.015863  3.690551  4.057274  3.666163  4.041198  3.997369  4.209606
# 42  3.858276  4.501480  4.228134  4.248210  4.021552  4.031306  4.223574
# 43  4.103631  3.657778  4.211005  4.056709  4.394398  3.772808  3.975740
# 44  4.051494  4.068664  4.085195  3.895248  4.285226  4.184135  4.165192
# 45  3.945318  3.741517  3.966480  3.905016  3.857691  3.949075  4.222751
# 46  4.020489  3.874124  4.018192  3.923221  4.034624  4.291500  3.926390
# 47  4.423241  3.761989  4.141624  4.151702  4.270818  4.008943  3.883139
# 48  3.872209  3.898451  4.042505  4.197345  4.296334  3.544156  3.852684
# 49  4.276953  4.037174  3.679434  4.099553  3.785141  3.654726  4.077668

# %%
np.mean(np.mean(data,axis = 0)) # overall mean
# Out:
# 4.0009736600101515

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
column_means = np.mean(data,axis = 0)
column_means
# Out:
# drug1    4.011291
# drug2    3.947379
# drug3    3.985907
# drug4    4.044451
# drug5    4.031444
# drug6    3.989000
# drug7    3.997344
# dtype: float64

# %%
overall_mean = np.sum(np.sum(data,axis = 0))/(len(data)*len(data.columns))
overall_mean
# Out:
# 4.000973660010151

# %%
SSC = np.sum((column_means-overall_mean)**2) * len(data)
SSC
# Out:
# 0.30905267316893076

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     each data points with its own mean

# %%
column_means
# Out:
# drug1    4.011291
# drug2    3.947379
# drug3    3.985907
# drug4    4.044451
# drug5    4.031444
# drug6    3.989000
# drug7    3.997344
# dtype: float64

# %%
SSE = 0
for group in data.columns:
    SSE += np.sum((data[group]-np.mean(data[group]))**2)

# %%
SSE
# Out:
# 14.009364156398236

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
overall_mean
# Out:
# 4.000973660010151

# %%
SST = 0

for grp in data.columns:
    for ele in data[grp]:
        SST += np.sum((ele-overall_mean)**2)
SST
# Out:
# 14.318416829567173

# %%
SST = SSC+SSE

# %%
SST
# Out:
# 14.318416829567168

# %% [markdown]
# ![image.png](attachment:image.png)m

# %%
n = len(data)* len(data.columns)
n
# Out:
# 350

# %%
c = len(data.columns)
c
# Out:
# 7

# %%
MSC = SSC/(c-1)

# %%
MSE = SSE/ (n-c)

# %%
MSC,MSE
# Out:
# (0.05150877886148846, 0.04084362727812897)

# %%
F_ratio = MSC/MSE
F_ratio
# Out:
# 1.2611215578561135

# %%
# cdf(x, dfn, dfd, loc=0, scale=1)

# %%
p_value = 1-stats.f.cdf(F_ratio,c-1,n-c)
p_value
# Out:
# 0.27476493428063553

# %%
F_critical = stats.f.ppf(0.95,c-1,n-c)
F_critical
# Out:
# 2.1250365781660565

# %%
stats.f_oneway(data["drug1"],
              data["drug2"],
              data["drug3"],
              data["drug4"],
              data["drug5"],
              data["drug6"],
               data["drug7"],
              )
# Out:
# F_onewayResult(statistic=1.2611215578561454, pvalue=0.27476493428062365)

# %%
if F_ratio > F_critical:
    print("reject null, all populations means are different ")
else:
    print("all population means are same")
    
if p_value < 0.05:
    print("reject null, all populations means are different ")
else:
    print("all population means are same")
# Out:
# all population means are same
# all population means are same

# %%
sns.kdeplot(drug1)
sns.kdeplot(drug2)
sns.kdeplot(drug3)
sns.kdeplot(drug4)
sns.kdeplot(drug5)
sns.kdeplot(drug6)
sns.kdeplot(drug7)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# one-way anova with same sample sizes.

# %%
def one_way_ANOVA(*X):
    data = pd.DataFrame(X).T
    print(data)
    column_means = np.mean(data,axis = 0)
    print()
    
    print(column_means)
    print()
    overall_mean = np.sum(np.sum(data,axis = 0))/(len(data)*len(data.columns))
    print(overall_mean)
    SSC = 0
    SSC = np.sum((column_means-overall_mean)**2) * len(data)
    
    SSE = 0
    for group in data.columns:
        SSE += np.sum((data[group]-np.mean(data[group]))**2)
        
    SST = 0
    for grp in data.columns:
        for ele in data[grp]:
            SST += np.sum((ele-overall_mean)**2)
    
    n = len(data)* len(data.columns)
    c = len(data.columns)
    print(n,c)
    MSC = SSC/(c-1)
    MSE = SSE/ (n-c)
    F_ratio = MSC/MSE
    
    print()
    print("SSC:",SSC)
    print("MSC:",MSC)
    print("SSE:",SSE)
    print("MSE:",MSE)
    print()
    
    print("F-Ratio: ",F_ratio)
    p_value = 1-stats.f.cdf(F_ratio,c-1,n-c)
    F_critical = stats.f.ppf(0.95,c-1,n-c)
    print("F_critical : ",F_critical)
    
    print("Results : ")
    if F_ratio > F_critical:
        print("reject null, all populations means are different ")
    else:
        print("all population means are same")
    
    
    if p_value < 0.05:
        print("reject null, all populations means are different ")
    else:
        print("all population means are same")
    return F_ratio,p_value

# %%
one_way_ANOVA([8,10,12,8,7],[12,11,9,14,4],[18,12,16,6,8],[13,9,12,16,15])
# Out:
#     0   1   2   3
# 0   8  12  18  13
# 1  10  11  12   9
# 2  12   9  16  12
# 3   8  14   6  16
# 4   7   4   8  15
#
# 0     9.0
# 1    10.0
# 2    12.0
# 3    13.0
# dtype: float64
#
# 11.0
# 20 4
#
# SSC: 50.0
# MSC: 16.666666666666668
# SSE: 208.0
# MSE: 13.0
#
# F-Ratio:  1.2820512820512822
# F_critical :  3.238871517453585
# Results :
# all population means are same
# all population means are same
# (1.2820512820512822, 0.3143594700488932)

# %%
stats.f_oneway([8,10,12,8,7],[12,11,9,14,4],[18,12,16,6,8],[13,9,12,16,15])
# Out:
# F_onewayResult(statistic=1.2820512820512822, pvalue=0.3143594700488932)

# %%
stats.f_oneway([8,9,11,12],[6,8,10,4],[14,12,18,9],[20,22,25,23])
# Out:
# F_onewayResult(statistic=25.221574344023324, pvalue=1.8124793267561276e-05)

# %%
# anova one way works with different sample sizes : 

G1 = norm.rvs(loc= 10.0,scale = 2.0,size = 400)
G2 = norm.rvs(loc= 10.3,scale = 2.1,size = 400)
G3 = norm.rvs(loc= 9.8, scale = 2.3,size = 500)

# %%
sns.distplot(G1)
sns.distplot(G2)
sns.distplot(G3)
plt.show()

# %%
stats.f_oneway(G1,G2,G3)
# Out:
# F_onewayResult(statistic=5.175751027394441, pvalue=0.005769290641501678)

# %%
stats.f.ppf(0.95,3-1,1300-3) # T-critical value
# Out:
# 3.002662301977574

# %%
1-stats.f.cdf(6.1366,3-1,1300-3)  # p-value
# Out:
# 0.002225558713822906

# %% [markdown]
#     as sample sizes increases , ANOVA can detect even very small differences in mean1 mean2 mean3.
#     variance in p-value depends on sample size of sample data

# %% [markdown]
#     under null hypothesis ,
#
#     Test Statistic F-Ratio (f) ~ F-distribution(c-1,n-c)

# %% [markdown]
# ## F-distribution
#
# - the F-distribution or F-ratio, also known as Snedecor's F distribution or the Fisher–Snedecor distribution is a continuous probability distribution that arises frequently as the null distribution of a test statistic, most notably in the analysis of variance (ANOVA) and other F-tests.

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # two-way Anova (w/o replication)

# %% [markdown]
# Lest assume that starbucksuses secret shoppers who appear to be customers to enter a store and document their experience in terms of customer service and quality.
# the secrete shopeers service standardize training by stabucks to ensure consistency and objectivity in their store reviews.
#
# we would like to know if a difference in secrete shoppers ratigs exists among the cities.
# are they all same ?
# is one significantly higher than other two ?
# are all three different from each other ?

# %%
df = pd.read_csv("Starbucks.csv",index_col=0)

# %%
df.index = ['shopper1', 'shopper2', 'shopper3', 'shopper4', 'shopper5',
       'shopper6']

# %%
df
# Out:
#           sydney  brisbane  melborne
# shopper1      75        75        90
# shopper2      70        70        70
# shopper3      50        55        75
# shopper4      65        60        85
# shopper5      80        65        80
# shopper6      65        65        65

# %% [markdown]
# SST = SSC + SSB + SSE

# %%
overall_mean = np.sum(np.sum(df,axis = 0))/(len(df)*len(df.columns))
overall_mean
# Out:
# 70.0

# %%
column_means = np.mean(df,axis = 0)
column_means
# Out:
# sydney      67.5
# brisbane    65.0
# melborne    77.5
# dtype: float64

# %%
block_means = np.mean(df,axis = 1)
block_means
# Out:
# shopper1    80.0
# shopper2    70.0
# shopper3    60.0
# shopper4    70.0
# shopper5    75.0
# shopper6    65.0
# dtype: float64

# %%
SST = 0
for col in df.columns:
    for r in df[col]:
        SST += ((r-overall_mean)**2)
SST
# Out:
# 1750.0

# %%
SSC = np.sum((column_means-overall_mean)**2)*len(df)
SSC
# Out:
# 525.0

# %%
SSB = np.sum((block_means-overall_mean)**2)*len(df.columns)
SSB
# Out:
# 750.0

# %%
SSE = SST-SSC-SSB
SSE
# Out:
# 475.0

# %% [raw]
# MSB/MSE
#
# MSC/MSB

# %%
dfc = len(df.columns)-1
dfc
# Out:
# 2

# %%
dfe = (len(df.columns)-1)*(len(df)-1)
dfe
# Out:
# 10

# %%
dft = len(df)*len(df.columns)-1
dft
# Out:
# 17

# %%
dfb = len(df)-1
dfb
# Out:
# 5

# %%
MSC = SSC/dfc
MSC
# Out:
# 262.5

# %%
MSB = SSB/dfb
MSB
# Out:
# 150.0

# %%
MSE = SSE/dfe
MSE
# Out:
# 47.5

# %%
F_column = MSC/MSE
F_column
# Out:
# 5.526315789473684

# %%
F_block = MSB/MSE
F_block
# Out:
# 3.1578947368421053

# %%
p_value_col = 1-stats.f.cdf(F_column,dfc,dfe)
p_value_col
# Out:
# 0.024180654296874993

# %%
p_value_block = 1-stats.f.cdf(F_block,dfb,dfe)
p_value_block
# Out:
# 0.05739916157799785

# %%
F_crtical_block = stats.f.ppf(0.95,dfb,dfe)
F_crtical_block
# Out:
# 3.3258345304130112

# %%
F_crtical_col = stats.f.ppf(0.95,dfc,dfe)
F_crtical_col
# Out:
# 4.1028210151304005

# %%
df.columns
# Out:
# Index(['sydney', 'brisbane', 'melborne'], dtype='object')

# %%
df.mean(axis = 0)
# Out:
# sydney      67.5
# brisbane    65.0
# melborne    77.5
# dtype: float64

# %%
df.reset_index()
# Out:
#       index  sydney  brisbane  melborne
# 0  shopper1      75        75        90
# 1  shopper2      70        70        70
# 2  shopper3      50        55        75
# 3  shopper4      65        60        85
# 4  shopper5      80        65        80
# 5  shopper6      65        65        65

# %%
df.plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
# using library

# %%
df = df.reset_index()

# %%
df = df.melt(id_vars="index",value_name="rating",var_name="city")

# %%
df
# Out:
#        index      city  rating
# 0   shopper1    sydney      75
# 1   shopper2    sydney      70
# 2   shopper3    sydney      50
# 3   shopper4    sydney      65
# 4   shopper5    sydney      80
# 5   shopper6    sydney      65
# 6   shopper1  brisbane      75
# 7   shopper2  brisbane      70
# 8   shopper3  brisbane      55
# 9   shopper4  brisbane      60
# 10  shopper5  brisbane      65
# 11  shopper6  brisbane      65
# 12  shopper1  melborne      90
# 13  shopper2  melborne      70
# 14  shopper3  melborne      75
# 15  shopper4  melborne      85
# 16  shopper5  melborne      80
# 17  shopper6  melborne      65

# %%
from statsmodels.formula.api import ols

# %%
ano2 = ols("rating~city+index",data = df).fit()

# %%
ano2

# %%
sm.stats.anova_lm(ano2,type=2)
# Out:
#             df  sum_sq  mean_sq         F    PR(>F)
# city       2.0   525.0    262.5  5.526316  0.024181
# index      5.0   750.0    150.0  3.157895  0.057399
# Residual  10.0   475.0     47.5       NaN       NaN

# %% [markdown]
# ## sm.statsmodel eexample

# %%
>>> import statsmodels.api as sm
>>> from statsmodels.formula.api import ols

# %%
>>> moore = sm.datasets.get_rdataset("Moore", "carData", cache=True) # load

# %%
moore
# Out:
# <class 'statsmodels.datasets.utils.Dataset'>

# %%
data = moore.data
data
# Out:
#    partner.status  conformity fcategory  fscore
# 0             low           8       low      37
# 1             low           4      high      57
# 2             low           8      high      65
# 3             low           7       low      20
# 4             low          10       low      36
# 5             low           6       low      18
# 6             low          12    medium      51
# 7             low           4    medium      44
# 8             low          13       low      31
# 9             low          12       low      36
# 10            low           4    medium      42
# 11            low          13      high      56
# 12            low           7       low      28
# 13            low           9    medium      43
# 14            low           9      high      65
# 15            low          24      high      57
# 16            low           6       low      28
# 17            low           7      high      61
# 18            low          23      high      57
# 19            low          13      high      55
# 20            low           8       low      17
# 21            low          12       low      35
# 22           high          19      high      68
# 23           high          12    medium      41
# 24           high          21       low      16
# 25           high           9      high      63
# 26           high          23       low      15
# 27           high           7      high      54
# 28           high          17    medium      48
# 29           high          14    medium      42
# 30           high          11      high      59
# 31           high          16    medium      45
# 32           high          15       low      30
# 33           high          20    medium      44
# 34           high           8    medium      42
# 35           high          12       low      22
# 36           high          14      high      52
# 37           high          14    medium      42
# 38           high          17    medium      41
# 39           high           7    medium      50
# 40           high          17    medium      39
# 41           high          13      high      57
# 42           high          16       low      35
# 43           high          10      high      52
# 44           high          15    medium      44

# %%
data = data.rename(columns={"partner.status" :
                             "partner_status"})

# %%
 moore_lm = ols('conformity ~ C(fcategory, Sum)*C(partner_status, Sum)',
                 data=data).fit()

# %%
>>> table = sm.stats.anova_lm(moore_lm, typ=2) # Type 2 Anova DataFrame
>>> print(table)
# Out:
#                                               sum_sq    df          F  \
# C(fcategory, Sum)                          11.614700   2.0   0.276958
# C(partner_status, Sum)                    212.213778   1.0  10.120692
# C(fcategory, Sum):C(partner_status, Sum)  175.488928   2.0   4.184623
# Residual                                  817.763961  39.0        NaN
#
#                                             PR(>F)
# C(fcategory, Sum)                         0.759564
# C(partner_status, Sum)                    0.002874
# C(fcategory, Sum):C(partner_status, Sum)  0.022572
# Residual                                       NaN

# %%
table
# Out:
#                                               sum_sq    df          F  \
# C(fcategory, Sum)                          11.614700   2.0   0.276958
# C(partner_status, Sum)                    212.213778   1.0  10.120692
# C(fcategory, Sum):C(partner_status, Sum)  175.488928   2.0   4.184623
# Residual                                  817.763961  39.0        NaN
#
#                                             PR(>F)
# C(fcategory, Sum)                         0.759564
# C(partner_status, Sum)                    0.002874
# C(fcategory, Sum):C(partner_status, Sum)  0.022572
# Residual                                       NaN
